# %%
# %%script bash
#
# # Version and configuration checks
# commands=(
#   "python --version"
#   "pip --version"
#   "ruby -v"
#   "bundle -v"
#   "gem -v"
#   "jupyter --version"
#   "jupyter kernelspec list"
#   "git config --global user.name"
#   "git config --global user.email"
# )
#
# for cmd in "${commands[@]}"; do
#   echo "### Command: $cmd"
#   bash -c "$cmd"
# done
# Out:
# ### Command: python --version
# Python 3.12.3
# ### Command: pip --version
# pip 24.0 from /home/rishab/RishbubS6/student/venv/lib/python3.12/site-packages/pip (python 3.12)
# ### Command: ruby -v
# ruby 3.2.3 (2024-01-18 revision 52bb2ac0a6) [x86_64-linux-gnu]
# ### Command: bundle -v
# Bundler version 2.7.2
# ### Command: gem -v
# 3.4.20
# ### Command: jupyter --version
# Selected Jupyter core packages...
# IPython          : 9.7.0
# ipykernel        : 7.1.0
# ipywidgets       : not installed
# jupyter_client   : 8.6.3
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.5.0
# nbclient         : 0.10.2
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.5.0
# qtconsole        : not installed
# traitlets        : 5.14.3
# ### Command: jupyter kernelspec list
# Available kernels:
#   python3    /home/rishab/RishbubS6/student/venv/share/jupyter/kernels/python3
# ### Command: git config --global user.name
# rishab
# ### Command: git config --global user.email
# rishab@shyamal.com

# %%
# %%script bash
#
# # Location of student repo, change to match your personal setup
# repoLocation=~/RishbubS6/student
#
# # Check for presence of repo and virtual environment
# commands=(
#
#   "ls --color=none -a ${repoLocation}"
#   "ls --color=none ${repoLocation}/venv/bin/activate"
# )
#
# for cmd in "${commands[@]}"; do
#   echo "### Command: $cmd"
#   bash -c "$cmd"
# done
# Out:
# ### Command: ls --color=none -a /home/rishab/RishbubS6/student
# .
# ..
# .bundle
# .env
# .git
# .github
# .gitignore
# .jekyll-metadata
# 404.html
# Gemfile
# Gemfile.lock
# LICENSE
# Makefile
# README.md
# README4YML.md
# _config.yml
# _data
# _includes
# _layouts
# _notebooks
# _posts
# _sass
# _site
# apple-touch-icon.png
# assets
# exam-predictor.html
# exercisegraphs.html
# favicon-16x16.png
# favicon-32x32.png
# favicon.ico
# git
# grade-predictor.html
# hacks
# images
# index.md
# kasm_design
# linuxcyberA
# login.css
# media
# navigation
# newsignup.html
# nohup.out
# requirements.txt
# scorepredictor.html
# scripts
# study-tracker.html
# testing.html
# venv
# ### Command: ls --color=none /home/rishab/RishbubS6/student/venv/bin/activate
# /home/rishab/RishbubS6/student/venv/bin/activate
